# %%
from pylab import plot, imshow, show, xlabel, ylabel
from numpy import loadtxt, array, zeros, sqrt, pi, sin
import matplotlib.pyplot as plot

UA = 1.495e11 #m
GM = 4*pi**2
m = 10e15


dt = 0.02
vel = []
rad = []
time = []
Energy = []
rn = 1
vn = 2*pi
theta = []
the = 0



for i in range(201):
    rn = rn+(vn*dt)
    a = GM/(rn**2)
    vn = vn+(a*dt)
    Et = -(GM*m)/(2*rn)
    the = the+(vn/rn)*dt
    rad.append (rn)
    time.append (dt*i)
    Energy.append (Et)
    theta.append (the)
    
    
print ("Método De Euler")    
plot.plot (time,rad)
show ()
plot.plot (rad, Energy)
show ()
plot.polar(theta,rad,'+')
plot.show()
# Out:
# Método De Euler

# %%
from pylab import plot, imshow, show, xlabel, ylabel
from numpy import loadtxt, array, zeros, sqrt, pi, sin
import matplotlib.pyplot as plot

UA = 1.495e11 #m
GM = 4*pi**2
m = 10e15


dt1 = 0.02
vel1 = []
rad1 = []
time1 = []
Energy1 = []
rn1 = 1
vn1 = 2*pi
theta1 = []
the1 = 0


for i in range(201):
    vn1 = vn1+((GM/(rn1**2))*dt1)
    rn1 = rn1+(vn1*dt1)
    Et1 = -(GM*m)/(2*rn1)
    the1 = the1+(vn1/rn1)*dt1
    rad1.append (rn1)
    time1.append (dt1*i)
    Energy1.append (Et1)
    theta1.append (the1)
    
    
print ("Método De Euler Mejorado")    
plot.plot (time1,rad1)
show ()
plot.plot (rad1, Energy1)
show ()
plot.polar(theta1,rad1,'+')
plot.show()
# Out:
# Método De Euler Mejorado
